# %% [markdown]
# Defining Path for dataset

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Big Data Analytics/Assignment # 2/")
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Big Data Analytics/Assignment # 2'

# %% [markdown]
# Importing Required Libraries

# %%
import argparse
from collections import defaultdict
import itertools as it
import pandas as pd

# %% [markdown]
# Reading CSV file

# %%
#Read csv file 
complete_df = pd.read_csv("CLEANED DATA.csv")
complete_df.head(30)
# Out:
#     Unnamed: 0  user_id  public  ...       movie_1        movie_2         movie_3
# 0       878127   878209       0  ...           NaN            NaN             NaN
# 1      1110624  1110683       0  ...      eroticke            NaN             NaN
# 2       546189   546175       0  ...       serialy        vojnove      historicke
# 3      1004479  1004537       0  ...       komedie        serialy         rodinne
# 4       623945   623925       0  ...       komedie     historicke             NaN
# 5      1524126  1524128       0  ...         akcne   dokumentarne         zahadne
# 6       765930   765778       0  ...         akcne         horory         komedie
# 7       861240   861245       0  ...         akcne            NaN             NaN
# 8       847279   847270       0  ...           NaN            NaN             NaN
# 9      1131700  1131745       0  ...           NaN            NaN             NaN
# 10      472232   472170       0  ...           NaN            NaN             NaN
# 11     1095758  1095745       0  ...       vojnove          akcne         komedie
# 12      259066   258970       0  ...     ano mam d            NaN             NaN
# 13     1231067  1231034       0  ...           NaN            NaN             NaN
# 14      598073   598106       0  ...        horory        vojnove      historicke
# 15      197495   197568       0  ...           NaN            NaN             NaN
# 16      242296   242363       0  ...      eroticke        komedie           dramy
# 17      186197   186100       0  ...         akcne        komedie         zahadne
# 18     1335652  1335685       0  ...        vsetky            NaN             NaN
# 19      479124   479164       0  ...       komedie        vojnove             NaN
# 20     1008458  1008490       0  ...           NaN            NaN             NaN
# 21      648428   648479       0  ...           NaN            NaN             NaN
# 22        5903     5813       0  ...         akcne          dramy          horory
# 23      410332   410338       0  ...           NaN            NaN             NaN
# 24     1567735  1567737       0  ...       komedie        serialy      romanticke
# 25      452207   452143       0  ...       komedie        serialy        muzikaly
# 26     1600338  1600340       0  ...  dokumentarne     romanticke         komedie
# 27     1053560  1053605       0  ...      fantasy          horory          sci-fi
# 28      687440   687457       0  ...  pearl harbor        titanic  stomp the yard
# 29      112383   112417       0  ...           NaN            NaN             NaN
#
# [30 rows x 47 columns]

# %%
# Data information 
complete_df.head(10)
for i in complete_df.columns:
    print(i,"\nuniqueValue:    ",len(complete_df[i].unique()),"\nTotal Value:  ",len(complete_df[i]),"    NotNULL",len(complete_df[i])-complete_df[i].isnull().sum(),"\nNULL: ",complete_df[i].isnull().sum(),"\n")
complete_df = complete_df[0:5000]
# Out:
# Unnamed: 0
# uniqueValue:     367150
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# user_id
# uniqueValue:     367150
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# public
# uniqueValue:     1
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# completion_percentage
# uniqueValue:     30
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# gender
# uniqueValue:     1
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# AGE
# uniqueValue:     112
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# I_am_working_in_field
# uniqueValue:     21226
# Total Value:   367150     NotNULL 202175
# NULL:  164975
#
# I_most_enjoy_good_food
# uniqueValue:     13235
# Total Value:   367150     NotNULL 125242
# NULL:  241908
#
# pets
# uniqueValue:     31851
# Total Value:   367150     NotNULL 178857
# NULL:  188293
#
# body_type
# uniqueValue:     19609
# Total Value:   367150     NotNULL 279029
# NULL:  88121
#
# my_eyesight
# uniqueValue:     8982
# Total Value:   367150     NotNULL 258446
# NULL:  108704
#
# eye_color
# uniqueValue:     11874
# Total Value:   367150     NotNULL 301382
# NULL:  65768
#
# hair_color
# uniqueValue:     13599
# Total Value:   367150     NotNULL 291221
# NULL:  75929
#
# hair_type
# uniqueValue:     14415
# Total Value:   367150     NotNULL 272446
# NULL:  94704
#
# completed_level_of_education
# uniqueValue:     9910
# Total Value:   367150     NotNULL 277330
# NULL:  89820
#
# relation_to_smoking
# uniqueValue:     16087
# Total Value:   367150     NotNULL 288659
# NULL:  78491
#
# relation_to_alcohol
# uniqueValue:     16170
# Total Value:   367150     NotNULL 265875
# NULL:  101275
#
# sign_in_zodiac
# uniqueValue:     14223
# Total Value:   367150     NotNULL 225556
# NULL:  141594
#
# on_pokec_i_am_looking_for
# uniqueValue:     19401
# Total Value:   367150     NotNULL 57339
# NULL:  309811
#
# love_is_for_me
# uniqueValue:     8420
# Total Value:   367150     NotNULL 22012
# NULL:  345138
#
# relation_to_casual_sex
# uniqueValue:     16037
# Total Value:   367150     NotNULL 27674
# NULL:  339476
#
# my_partner_should_be
# uniqueValue:     10585
# Total Value:   367150     NotNULL 22583
# NULL:  344567
#
# marital_status
# uniqueValue:     11157
# Total Value:   367150     NotNULL 268656
# NULL:  98494
#
# I_like_watching_movie
# uniqueValue:     7923
# Total Value:   367150     NotNULL 117144
# NULL:  250006
#
# I_mostly_like_listening_to_music
# uniqueValue:     7121
# Total Value:   367150     NotNULL 69075
# NULL:  298075
#
# the_idea_of_good_evening
# uniqueValue:     7665
# Total Value:   367150     NotNULL 21758
# NULL:  345392
#
# I_like_specialties_from_kitchen
# uniqueValue:     9458
# Total Value:   367150     NotNULL 105182
# NULL:  261968
#
# I_am_going_to_concerts
# uniqueValue:     12963
# Total Value:   367150     NotNULL 105482
# NULL:  261668
#
# profession
# uniqueValue:     21107
# Total Value:   367150     NotNULL 195975
# NULL:  171175
#
# num_unique
# uniqueValue:     13
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# height_cm
# uniqueValue:     524
# Total Value:   367150     NotNULL 351169
# NULL:  15981
#
# weight_kg
# uniqueValue:     543
# Total Value:   367150     NotNULL 301897
# NULL:  65253
#
# language_1
# uniqueValue:     44980
# Total Value:   367150     NotNULL 348477
# NULL:  18673
#
# user_region
# uniqueValue:     10
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# town
# uniqueValue:     183
# Total Value:   367150     NotNULL 367150
# NULL:  0
#
# color_1
# uniqueValue:     2866
# Total Value:   367150     NotNULL 356027
# NULL:  11123
#
# book_1
# uniqueValue:     10436
# Total Value:   367150     NotNULL 252295
# NULL:  114855
#
# book_2
# uniqueValue:     10118
# Total Value:   367150     NotNULL 233043
# NULL:  134107
#
# passive_sports_1
# uniqueValue:     9893
# Total Value:   367150     NotNULL 218133
# NULL:  149017
#
# active_sports_1
# uniqueValue:     12851
# Total Value:   367150     NotNULL 232712
# NULL:  134438
#
# hobby_1
# uniqueValue:     31741
# Total Value:   367150     NotNULL 350132
# NULL:  17018
#
# hobby_2
# uniqueValue:     12863
# Total Value:   367150     NotNULL 293694
# NULL:  73456
#
# hobby_3
# uniqueValue:     9867
# Total Value:   367150     NotNULL 273290
# NULL:  93860
#
# music_1
# uniqueValue:     12715
# Total Value:   367150     NotNULL 269299
# NULL:  97851
#
# movie_1
# uniqueValue:     7536
# Total Value:   367150     NotNULL 330133
# NULL:  37017
#
# movie_2
# uniqueValue:     3091
# Total Value:   367150     NotNULL 285489
# NULL:  81661
#
# movie_3
# uniqueValue:     2503
# Total Value:   367150     NotNULL 259352
# NULL:  107798

# %% [markdown]
# ### Extracting Required Columns from Dataset

# %%
# col_name = ["town","user_region","eye_color","hair_color","body_type","completed_level_of_education","relation_to_smoking"]
col_name = ['eye_color','hair_color','hair_type','completed_level_of_education','sign_in_zodiac','language_1','hobby_1','music_1','movie_1']
# Creating Required Matrix 
df = pd.DataFrame([])
tagged_items = dict()
index = 0
for i in col_name:
    # Find unique values in ith column of dataframe and create a dictionary
    for value in complete_df[i].unique():
        tagged_items[value] = index
        index+=1
    # Create a vector with integer values by replacing its values with dictionary values  
    transformed_df = complete_df[i].replace(tagged_items)
    # Concatinate it to new Dataframe which will 
    df = pd.concat([df,transformed_df],axis=1)
    print(i,"- Done")
# df = df[0:1000]
print("Shape of DataFrame",df.shape,"\n______________________________________________________________________________\n\nTransformed DataFrame\n",df)
# Out:
# eye_color - Done
# hair_color - Done
# hair_type - Done
# completed_level_of_education - Done
# sign_in_zodiac - Done
# language_1 - Done
# hobby_1 - Done
# music_1 - Done
# movie_1 - Done
# Shape of DataFrame (5000, 9)
# ______________________________________________________________________________
#
# Transformed DataFrame
#        eye_color  hair_color  hair_type  ...  hobby_1  music_1  movie_1
# 0             0         346        706  ...     2378     2968     3325
# 1             1         346        707  ...     2379     2968     3326
# 2             0         347        707  ...     2380     2969     3327
# 3             2         348        708  ...     2381     2968     3328
# 4             2         349        706  ...     2380     2968     3328
# ...         ...         ...        ...  ...      ...      ...      ...
# 4995          2         348        718  ...     2380     2968     3328
# 4996          2         705        706  ...     2379     2968     3327
# 4997          3         349        706  ...     2378     2969     3329
# 4998          0         346        707  ...     2405     2982     3330
# 4999          2         348       1076  ...     2388     2969     3345
#
# [5000 rows x 9 columns]

# %% [markdown]
# Defining Hash Function

# %%
def hash(num1, num2):
  ''' Hash function for the hash table '''
  return (num1 ^ num2) % df[col_name[-1]].max()

# %% [markdown]
# Defining Bitmap Function

# %%
def create_bitmap(hash_table, threshold):
  ''' Convert the hash table into a bitmap '''
  bit_map = []
  for key, value in hash_table.items():
    if value < threshold:
      bit_map.insert(key, 0)
    else:
      bit_map.insert(key, 1)

  return bit_map

# %% [markdown]
# Creating Candidate itemset

# %%
def create_candidate_item_set(dataset_file):
    ''' Create a dictionary of all candidate item sets from the data set with their corresponding count '''

    candidate_item_list = dict()
    baskets = []

    buckets = {}

    for _ ,row in dataset_file.iterrows():
        ##
        # Create the candidate item set
        ##
        num_list = list(row)
        # create a list of all baskets
        baskets.append(num_list)
        # create a dictionary with a count of each individual item
        for item in num_list:
            if item not in candidate_item_list:
                candidate_item_list[item] = 1
            else:
                candidate_item_list[item] += 1
        ##
        # Create pairs of unique items in each bucket
        ##
        pairs = list(it.combinations(num_list, 2))
        for pair in pairs:
            index = hash(pair[0], pair[1]) 
            buckets[index] = 1 if index not in buckets else buckets[index]+1
    return candidate_item_list, baskets, buckets

# candidate_item_list, baskets, buckets = create_candidate_item_set(df)
# print(candidate_item_list,"\n", baskets,"\n", buckets )

# %% [markdown]
# Defining function to find Frequent Itemset

# %%
def create_frequent_item_set(item_list, min_threshold):
    ''' Return the frequent items from the candidate_item_list that meet the min_support '''
    item_list_new = {}
    #delete items that dont meet min threshold
    for key, value in item_list.items():
        # Check item key and its count 
        # If count of item is greater then threshold then value will be kept
        if value >= min_threshold:
            item_list_new[key] = value
    return item_list_new.keys()

# %% [markdown]
# Defining Function to keep count of freqent itemset in a basket

# %%
def count(item_list, baskets):
    ''' Count the number of frequent item sets in the baskets '''
    count = dict(zip(item_list, [1]*len(item_list)))
    for basket in baskets:
        for key in count:
          if set(list(key)) < set(basket):
            count[key] += 1 
    return count

# %%
def join(freq_item_sets, k):
  ''' Generate the joint transactions from candidate sets of size k '''
  
  # k is the size of each item set
  if k <= 2: 
    return list(it.combinations(freq_item_sets, k))
  else:
    return list(it.combinations(set(a for b in freq_item_sets for a in b),k))

# %% [markdown]
# Defining PCY Algorithm

# %%
def PCY(dataset_file, threshold):  
  
    C1, baskets, buckets = create_candidate_item_set(dataset_file)
    bitmap = create_bitmap(buckets, threshold)
    F1_items = create_frequent_item_set(C1, threshold)
#   # hash each frequent item into the bitmap and remove non frequent pairs
    frequent_pairs = join(F1_items, 2)
    for pair in frequent_pairs:
        hash_value = hash(pair[0], pair[1])
        if bitmap[hash_value] is not 1:
            frequent_pairs.remove(pair)
    if not frequent_pairs:
        return None
    else:
        # Initialize with possible frequent pairs
        L = [frequent_pairs]
        items = count(L[0], baskets)
        # check which frequent pairs meet minimum threshold value
        L[0] = create_frequent_item_set(items, threshold)
  

        k = 3

    while(True):
        new_list = join(L[k-3], k)
        items = count(new_list, baskets)

        Fk_items = create_frequent_item_set(items, threshold)
        if len(Fk_items) > 0:
            L.append(Fk_items)
            k+=1
        else:
            break
    
    
    return L[k-3]

# %% [markdown]
# Defining Function to get output in required form

# %%
def FinalResult(result, tagged_items):
    final_result = list()
    final_result = list()
    key_list = list(tagged_items.keys())
    val_list = list(tagged_items.values())
    for bucket in result:
        temp_tuple = tuple()
        for item in bucket:
            if item in range(0,hc[0]):
                value = ("eye_colour",key_list[item])
            else:            
                value = ("hair_colour",key_list[item])
            temp_tuple+=(value,)
        if (temp_tuple[1][0] != temp_tuple[0][0]):
            if temp_tuple[0][0] == 'eye_colour':
                print(temp_tuple)
                final_result.append(temp_tuple)
            else:
                temp_tup = ((temp_tuple[1][0],temp_tuple[1][1]),(temp_tuple[0][0],temp_tuple[0][1]))
                print(temp_tup)
                final_result.append(temp_tup)

# %% [markdown]
# Main Execution

# %%
if __name__ == '__main__':
    support = len(df)*0.075
    print('Frequent Item Sets with threshold:',support )
    result = PCY(df, support)
# Out:
# Frequent Item Sets with threshold: 375.0

# %%
final_result = list()

key_list = list(tagged_items.keys())
val_list = list(tagged_items.values())
for bucket in result:
    temp_tuple = tuple()
    for item in bucket:
        temp_tuple+=(key_list[item],)

    final_result.append(temp_tuple)

final_result,len(final_result)
# Out:
# ([('vsetkyd predsa', 'hnede', 'tmavehnede'),
#   ('vsetkyd predsa', 'anjelov', 'tmavehnede'),
#   ('hnede', 'co sa da', 'anjelov'),
#   ('hnede', 'co sa da', 'tmavehnede'),
#   ('hnede', 'co sa da', 'vsetky '),
#   ('hnede', 'zblizenci', 'tmavehnede'),
#   ('hnede', 'nevijadrujem sa', 'tmavehnede'),
#   ('hnede', 'rovne a huste', 'tmavehnede'),
#   ('hnede', 'anjelov', 'tmavehnede'),
#   ('co sa da', 'zblizenci', 'anjelov'),
#   ('co sa da', 'zblizenci', 'vsetky '),
#   ('co sa da', 'nevijadrujem sa', 'vsetky '),
#   ('co sa da', 'anjelov', 'tmavehnede'),
#   ('co sa da', 'anjelov', 'vsetky '),
#   ('co sa da', 'tmavehnede', 'vsetky '),
#   ('zblizenci', 'anjelov', 'tmavehnede')],
#  16)

# %% [markdown]
# These are The frequent itemset - End
# Thanks
